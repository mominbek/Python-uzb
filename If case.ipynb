# %% [markdown]
# # 6 - dars case

# %%
#1
a = int(input("Hafta kuni = "))
a = a%7
if   a==1:
    print("Dushanba")
elif a==2:
    print("Seshanba")
elif a==3:
    print("Chorshanba")    
elif a==4:
    print("Payshanba")
elif a==5:
    print("Juma")
elif a==6:
    print("Shanba")
elif a==0:
    print("Yakshanba")
else: 
    print("Notogri qiymat kiritilgan")
# Out:
# Hafta kuni = 25
# Payshanba

# %%
#2
k = int(input('baho = '))
if k==1:
    print('yomon')
elif k==2:
    print('qoniqarsiz')
elif k==3:
    print('qoniqarli')
elif k==4:
    print('yaxshi')
elif k==5:
    print("a'lo")
else:
    print('xato')
# Out:
# baho = 12
# xato

# %%
#3
a = int(input('Oy raqami => '))
if a==12 or 1<=a<=2:
    print('Qish ')
elif 3<=a<=5:
    print('Bahor')
elif 6<=a<=8:
    print('Yoz')
elif 9<=a<=11:
    print('Kuz')
else :
    print('oy raqami xato')
# Out:
# Oy raqami => 11
# Kuz

# %%
#4
a = int(input('Oy raqami => '))
if a==1 or a==3 or a==5 or a==7 or a==8 or a==10 or a==12:
    print('31 kun')
elif a==28:
    print('28 kun')
elif a==4 or a==6 or a==9 or a==11:
    print('30 kun')
# Out:
# Oy raqami => 6
# 30 kun

# %%
#5
a = float(input('a = '))
b = float(input('b = '))
x = int(input('amal raqami 1 - 4 '))
if x==1:
    print('a+b = ', a+b)
elif x==2:
    print('a-b = ', a-b)
elif x==3:
    print('a/b = ', a/b)
elif x==4:
    print('',a*b)
# Out:
# a = 12
# b = 45
# amal raqami 1 - 4 3
# a/b =  0.26666666666666666

# %%
#6
L = float(input("L = "))
n = int(input('n = '))
if n==1:
    print(L, 'detsimetr = ', L/10, 'metr' )
elif n==2:
    print(L, 'kilometr = ', L*1000, 'metr' )
elif n==3:
    print(L,  ' metr' )
elif n==4:
    print(L, 'millimetr = ', L/1000, 'metr' )
elif n==5:
    print(L, 'santimetr = ', L/100, 'metr' )
# Out:
# L = 1653151
# n = 5
# 1653151.0 santimetr =  16531.51 metr

# %%
#7
L = float(input("L = "))
n = int(input('n = '))
if n==1:
    print(L, 'kilogram ')
elif n==2:
    print(L, 'milligram = ', L/(10**6), 'kilogram' )
elif n==3:
    print(L, 'gram = ', L/(10**3), 'kilogram' )
elif n==4:
    print(L, 'tonna = ', L*1000, 'kilogram' )
elif n==5:
    print(L, 'sentner = ', L*100, 'kilogram' )
# Out:
# L = 1651
# n = 3
# 1651.0 gram =  1.651 kilogram

# %%
#8
d = int(input('kun = '))
m = int(input('oy = '))
if m==1:
    print(d, '- yanvar')
elif m==2:
    print(d, '- fevral')
elif m==3:
    print(d, '- mart')
elif m==4:
    print(d, '- aprel')
elif m==5:
    print(d, '- may')
elif m==6:
    print(d, '- iyun')
elif m==7:
    print(d, '- iyul')
elif m==8:
    print(d, '- avgust')
elif m==9:
    print(d, '- sentyabr')
elif m==10:
    print(d, '- oktyabr')
elif m==11:
    print(d, '- noyabr')
elif m==12:
    print(d, '- dekabr')
else: 
    print('oy yoki kun xato')
# Out:
# kun = 12
# oy = 5
# 12 - may

# %%
#9
d = int(input('kun = '))
m = int(input('oy = '))
if m==1:
    print(d+1, '- yanvar')
elif m==2:
    print(d+1, '- fevral')
elif m==3:
    print(d+1, '- mart')
elif m==4:
    print(d+1, '- aprel')
elif m==5:
    print(d+1, '- may')
elif m==6:
    print(d+1, '- iyun')
elif m==7:
    print(d+1, '- iyul')
elif m==8:
    print(d+1, '- avgust')
elif m==9:
    print(d+1, '- sentyabr')
elif m==10:
    print(d+1, '- oktyabr')
elif m==11:
    print(d+1, '- noyabr')
elif m==12:
    print(d+1, '- dekabr')
else: 
    print('oy yoki kun xato')
# Out:
# kun = 12
# oy = 6
# 13 - iyun

# %%
#10
y = str(input('robot yunalishi (s, j, q, g) => ' ))
k = int(input('komanda (0, 1, 2)=> '))
s = 'shimol' 
j = 'janub'
q = 'sharq'
g = 'g\'arb'
if y=='s' and k==0:
    print("Robot yo'nalishi => ", s)
elif y=='s' and k==1:
    print("Robot yo'nalishi => ", q)
elif y=='s' and k==2:
    print("Robot yo'nalishi => ", g)
elif y=='j' and k==0:
    print("Robot yo'nalishi => ", j)
elif y=='j' and k==1:
    print("Robot yo'nalishi => ", g)
elif y=='j' and k==2:
    print("Robot yo'nalishi => ", q)
elif y=='q' and k==0:
    print("Robot yo'nalishi => ", q)
elif y=='q' and k==1:
    print("Robot yo'nalishi => ", j)
elif y=='q' and k==2:
    print("Robot yo'nalishi => ", s)
elif y=='g' and k==0:
    print("Robot yo'nalishi => ", g)
elif y=='g' and k==1:
    print("Robot yo'nalishi => ", s)
elif y=='g' and k==2:
    print("Robot yo'nalishi => ", j)
# Out:
# robot yunalishi (s, j, q, g) => j
# komanda (0, 1, 2)=> 0
# Robot yo'nalishi =>  janub

# %%
#11

# %%
#12
k = int(input('doira elementi (1-4) -> '))
l = int(input('uzunligi = '))
pi = 3.14
if k == 1:
    print('Radius = ', l)
    print('D = ', 2*l, ' L = ', 2*pi*l, ' S = ', pi*l*l )
elif k==2:
    print('D = ', l)
    print('R = ', l/2, " L = ", pi*l, ' S = ', pi*l*l/4 )
elif k==3:
    print('L = ', l)
    print('R = ', l/(2*pi), " D = ", l/pi, ' S = ', (l/(2*pi)**2 ))
elif k==4:
    print('S = ', l)
    print('R = ', (l/pi)**0.5, " D = ", (l/pi)**0.5*2, ' L = ', 2*pi*(l/pi)**0.5)
else:
    print('Error')
# Out:
# doira elementi (1-4) -> 3
# uzunligi = 12
# L =  12
# R =  1.910828025477707  D =  3.821656050955414  S =  0.3042719785792527

# %%
#13
m = int(input("Element raqami (1-4)) => "))
l = int(input('uzunligi = '))
a = (4*S/(3**0.5)**0.5
if m==1:
     print(' a = ', l)
     print("R1 = ", a*(3**0.5)/6, ' R2 = ', a*(3**0.5)/3, ' S = ', a*a*(3**0.5)/4)
elif m==2:
     print(' R1 = ', l)
     print(' a = ', 6*l/(3**0.5), " R2 = ", 2*l, ' S = '(6*l/(3**0.5)**2*(3**0.5)/4),

# %%
#qo'shimcha
d = int(input('kun = '))
m = int(input('oy = '))
y = int(input('yil = '))

if m==1 and d!=1:
    print(d-1, '- yanvar', y, ' - yil')
elif m==2 and d!=1:
    print(d-1, '- fevral', y, ' - yil')
elif m==3 and d!=1:
    print(d-1, '- mart', y, ' - yil')
elif m==4 and d!=1:
    print(d-1, '- aprel', y, ' - yil')
elif m==5 and d!=1:
    print(d-1, '- may', y, ' - yil')
elif m==6 and d!=1:
    print(d-1, '- iyun', y, ' - yil')
elif m==7 and d!=1:
    print(d-1, '- iyul', y, ' - yil')
elif m==8 and d!=1:
    print(d-1, '- avgust', y, ' - yil')
elif m==9 and d!=1:
    print(d-1, '- sentyabr', y, ' - yil')
elif m==10 and d!=1:
    print(d-1, '- oktyabr', y, ' - yil')
elif m==11 and d!=1:
    print(d-1, '- noyabr', y, ' - yil')
elif m==12 and d!=1:
    print(d-1, '- dekabr', y, ' - yil')
    
if m-1=1 and d==1:
    print(31, '- yanvar', y, ' - yil')
elif m-1==2 and d==1:
    print(28, '- fevral', y, ' - yil')
elif m-1==3 and d==1:
    print(31, '- mart', y, ' - yil')
elif m-1==4 and d==1:
    print(30, '- aprel', y, ' - yil')
elif m-1==5 and d==1:
    print(31, '- may', y, ' - yil')
elif m-1==6 and d==1:
    print(30, '- iyun', y, ' - yil')
elif m-1==7 and d==1:
    print(31, '- iyul', y, ' - yil')
elif m-1==8 and d==1:
    print(31, '- avgust', y, ' - yil')
elif m-1==9 and d==1:
    print(30, '- sentyabr', y, ' - yil')
elif m-1==10 and d==1:
    print(31, '- oktyabr', y, ' - yil')
elif m-1==11 and d==1:
    print(30, '- noyabr', y, ' - yil')
elif m==1 and d==1:
    print(31, '- dekabr', y-1, ' - yil')
else: 
    print('oy yoki kun xato')

# %%
#sonni so'zga aylantirish
n = int(input("N (0-999mln) = "))
n9 = n//10**8
n8 = n%10**8//10**7
n7 = n%10**7//10**6
n6 = n%10**6//10**5
n5 = n%10**5//10**4
n4 = n%10**4//10**3
n3 = n%10**3//10**2
n2 = n%10**2//10
n1 = n%10

if n//(10**6)>0:
    if n9==1:
        n9 = 'bir yuz'
    if n9==2:
        n9 = 'ikki yuz'
    if n9==3:
        n9 = 'uch yuz'
    if n9==4:
        n9 = 'to\'rt yuz'
    if n9==5:
        n9 = 'besh yuz'
    if n9==6:
        n9 = 'olti yuz'
    if n9==7:
        n9 = 'yetti yuz'
    if n9==8:
        n9 = 'sakkiz yuz'
    if n9==9:
        n9 = 'to\'qqiz yuz'
    if n9==0:
        n9 = ''
    if n8 == 1:
        n8 = "o'n"
    if n8 == 2:
        n8 = "yigirma"
    if n8 == 3:
        n8 = "o'tiiz"
    if n8 == 4:
        n8 = "qirq"
    if n8 == 5:
        n8 = "ellik"
    if n8 == 6:
        n8 = "olmish"
    if n8 == 7:
        n8 = "yetmish"
    if n8 == 8:
        n8 = "sakson"
    if n8 == 1:
        n8 = "to'qson"
    if n8 == 0:
        n8 = ""
    if n7==1:
        n7 = 'bir'
    if n7==2:
        n7 = 'ikki'
    if n7==3:
        n7 = 'uch'
    if n7==4:
        n7 = 'to\'rt'
    if n7==5:
        n7 = 'besh'
    if n7==6:
        n7 = 'olti'
    if n7==7:
        n7 = 'yetti'
    if n7==8:
        n7 = 'sakkiz'
    if n7==9:
        n7 = 'to\'qqiz'   
    if n7==0:
        n7 = ''
    print(n9, n8, n7, 'million', end=' ')
    
if (n%10**6)//(10**3)>0:
    if n6==1:
        n6 = 'bir yuz'
    if n6==2:
        n6 = 'ikki yuz'
    if n6==3:
        n6 = 'uch yuz'
    if n6==4:
        n6 = 'to\'rt yuz'
    if n6==5:
        n6 = 'besh yuz'
    if n6==6:
        n6 = 'olti yuz'
    if n6==7:
        n6 = 'yetti yuz'
    if n6==8:
        n6 = 'sakkiz yuz'
    if n6==9:
        n6 = 'to\'qqiz yuz'
    if n6==0:
        n6 = ''
    if n5 == 1:
        n5 = "o'n"
    if n5 == 2:
        n5 = "yigirma"
    if n5 == 3:
        n5 = "o'tiiz"
    if n5 == 4:
        n5 = "qirq"
    if n5 == 5:
        n5 = "ellik"
    if n5 == 6:
        n5 = "olmish"
    if n5 == 7:
        n5 = "yetmish"
    if n5 == 8:
        n5 = "sakson"
    if n5 == 9:
        n5 = "to'qson"
    if n5 == 0:
        n5 = ""
    if n4==1:
        n4 = 'bir'
    if n4==2:
        n4 = 'ikki'
    if n4==3:
        n4 = 'uch'
    if n4==4:
        n4 = 'to\'rt'
    if n4==5:
        n4 = 'besh'
    if n4==6:
        n4 = 'olti'
    if n4==7:
        n4 = 'yetti'
    if n4==8:
        n4 = 'sakkiz'
    if n4==9:
        n4 = 'to\'qqiz'                            
    if n4==0:
        n4 = ''                            
    print(n6, n5, n4, 'ming', end=' ')    

if n3==1:
    n3 = 'bir yuz'
if n3==2:
    n3 = 'ikki yuz'
if n3==3:
    n3 = 'uch yuz'
if n3==4:
    n3 = 'to\'rt yuz'
if n3==5:
    n3 = 'besh yuz'
if n3==6:
    n3 = 'olti yuz'
if n3==7:
    n3 = 'yetti yuz'
if n3==8:
    n3 = 'sakkiz yuz'
if n3==9:
    n3 = 'to\'qqiz yuz'
if n3==0:
    n3 = ''
if n2 == 1:
    n2 = "o'n"
if n2 == 2:
    n2 = "yigirma"
if n2 == 3:
    n2 = "o'tiiz"
if n2 == 4:
    n2 = "qirq"
if n2 == 5:
    n2 = "ellik"
if n2 == 6:
    n2 = "olmish"
if n2 == 7:
    n2 = "yetmish"
if n2 == 8:
    n2 = "sakson"
if n2 == 1:
    n2 = "to'qson"   
if n2 == 0:
    n2 = "" 
    
if n1==1:
    n1 = 'bir'
if n1==2:
    n1 = 'ikki'
if n1==3:
    n1 = 'uch'
if n1==4:
    n1 = 'to\'rt'
if n1==5:
    n1 = 'besh'
if n1==6:
    n1 = 'olti'
if n1==7:
    n1 = 'yetti'
if n1==8:
    n1 = 'sakkiz'
if n1==9:
    n1 = 'to\'qqiz'
if n1==0:
    n1 = ''
    
print(n3,n2,n1)
# Out:
# N (0-999mln) = 1010000
#   bir million  o'n  ming

# %%
#case 19
y = int(input('Yil = '))
rang = (y-1984)%5
if rang ==0:
    print('yashil', end=' ')
if rang ==1:
    print('qizil', end=' ')
if rang ==2:
    print('sariq', end=' ')
if rang ==3:
    print('oq', end=' ')
if rang ==4:
    print('qora', end=' ')
muchal = (y-1984)%12
if muchal == 0:
    print('sichqon', end=' ')
if muchal == 1:
    print('sigir', end=' ')
if muchal == 2:
    print('yulbars', end=' ')
if muchal == 3:
    print('quyon', end=' ')
if muchal == 4:
    print('ajdar', end=' ')
if muchal == 5:
    print('ilon', end=' ')
if muchal == 6:
    print('ot', end=' ')
if muchal == 7:
    print('qo\'y', end=' ')
if muchal == 8:
    print('maymun', end=' ')
if muchal == 9:
    print('tovuq', end=' ')
if muchal == 10:
    print('it', end=' ')
if muchal == 11:
    print("to'ng'iz", end=' ')
# Out:
# Yil = 1983
# qora to'ng'iz

# %%
#case 20
d = int(input('kun = '))
m = int(input('oy = '))
if 1<=m<=12 and 1<=d<=31:
    if m == 1 and d>=20 or m==2 and d<=18:
        print("Qovg'a")
    if m == 2 and 29>=d>=19 or m==3 and d<=20:
        print("Baliq")
    else:
        print("Xato sana")
    if m == 3 and d>=21 or m==4 and d<=19:
        print("Qo'y")
    if m == 4 and d>=20 or m==5 and d<=20:
        print("Buzoq")
    if m == 5 and d>=21 or m==6 and d<=21:
        print("Egizaklar")
    if m == 6 and d>=22 or m==7 and d<=22:
        print("Qisqichbaqa")
    if m == 7 and d>=23 or m==8 and d<=22:
        print("Arslon")
    if m == 8 and d>=23 or m==9 and d<=22:
        print("Parizod")
    if m == 9 and d>=23 or m==10 and d<=22:
        print("Tarozi")
    if m == 10 and d>=23 or m==11 and d<=22:
        print("Chayon")
    if m == 11 and d>=21 or m==12 and d<=21:
        print("O'qotar")
    if m == 12 and d>=22 or m==1 and d<=19:
        print("Echki")
else:
    print("Xato sana")
# Out:
# kun = 30
# oy = 2
# Xato sana

# %%
kun = int(input("Kun => "))
oy = int(input("Oy => "))
yil = int(input("Yil => "))

if 1<=kun<31 and 1<=oy<=12:
    if yil%4!=0:
        if oy==1 or oy==3 or oy==5 or oy==7 or oy==8 or oy==10 or oy==12:
            if kun+2==32 and oy!=12:
                print('1',oy+1, yil, sep='.')
            if kun+2==33 and oy!=12:
                print('2',oy+1, yil, sep='.')
            if kun+2==32 and oy==12:
                print('1','1', yil+1, sep='.')
            if kun+2==33 and oy==12:
                print('2','1', yil+1, sep='.')
        if oy==4 or oy==6 or oy==9 or oy==11:
            if kun+2==31:
                print('1',oy+1, yil, sep='.')
            if kun+2==32:
                print('2',oy+1, yil, sep='.')
        if oy==2:
            if kun+2==29:
                print('1',oy+1, yil, sep='.')
            if kun+2==30:
                print('2',oy+1, yil, sep='.')
    else:
        print(kun+2, oy, yil, sep='.')
    if yil%4==0 or yil%100!=0 and yil%400==0:
        if oy==1 or oy==3 or oy==5 or oy==7 or oy==8 or oy==10 or oy==12:
            if kun+2==32 and oy!=12:
                print('1',oy+1, yil, sep='.')
            if kun+2==33 and oy!=12:
                print('2',oy+1, yil, sep='.')
            if kun+2==32 and oy==12:
                print('1','1', yil+1, sep='.')
            if kun+2==33 and oy==12:
                print('2','1', yil+1, sep='.')
        if oy==4 or oy==6 or oy==9 or oy==11:
            if kun+2==31:
                print('1',oy+1, yil, sep='.')
            if kun+2==32:
                print('2',oy+1, yil, sep='.')
        if oy==2:
            if kun+2==30:
                print('1',oy+1, yil, sep='.')
            if kun+2==31:
                print('2',oy+1, yil, sep='.')
    else:
        print(kun+2, oy, yil, sep='.')
else:
    print('sana xato kiritilgan')
# Out:
# Kun => 45
# Oy => 12
# Yil => 2000
# sana xato kiritilgan
