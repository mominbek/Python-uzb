# %%
#sonni so'zga aylantirish
n = int(input("N (0-999mln) = "))
n9 = n//10**8
n8 = n%10**8//10**7
n7 = n%10**7//10**6
n6 = n%10**6//10**5
n5 = n%10**5//10**4
n4 = n%10**4//10**3
n3 = n%10**3//10**2
n2 = n%10**2//10
n1 = n%10

if n//(10**6)>0:
    if n9==1:
        n9 = 'bir yuz'
    if n9==2:
        n9 = 'ikki yuz'
    if n9==3:
        n9 = 'uch yuz'
    if n9==4:
        n9 = 'to\'rt yuz'
    if n9==5:
        n9 = 'besh yuz'
    if n9==6:
        n9 = 'olti yuz'
    if n9==7:
        n9 = 'yetti yuz'
    if n9==8:
        n9 = 'sakkiz yuz'
    if n9==9:
        n9 = 'to\'qqiz yuz'
    if n8 == 1:
        n8 = "o'n"
    if n8 == 2:
        n8 = "yigirma"
    if n8 == 3:
        n8 = "o'tiiz"
    if n8 == 4:
        n8 = "qirq"
    if n8 == 5:
        n8 = "ellik"
    if n8 == 6:
        n8 = "olmish"
    if n8 == 7:
        n8 = "yetmish"
    if n8 == 8:
        n8 = "sakson"
    if n8 == 1:
        n8 = "to'qson"
    if n7==1:
        n7 = 'bir'
    if n7==2:
        n7 = 'ikki'
    if n7==3:
        n7 = 'uch'
    if n7==4:
        n7 = 'to\'rt'
    if n7==5:
        n7 = 'besh'
    if n7==6:
        n7 = 'olti'
    if n7==7:
        n7 = 'yetti'
    if n7==8:
        n7 = 'sakkiz'
    if n7==9:
        n7 = 'to\'qqiz'                            
    print(n9, n8, n7, 'million', end=' ')
    
if (n%10**6)//(10**3)>0:
    if n6==1:
        n6 = 'bir yuz'
    if n6==2:
        n6 = 'ikki yuz'
    if n6==3:
        n6 = 'uch yuz'
    if n6==4:
        n6 = 'to\'rt yuz'
    if n6==5:
        n6 = 'besh yuz'
    if n6==6:
        n6 = 'olti yuz'
    if n6==7:
        n6 = 'yetti yuz'
    if n6==8:
        n6 = 'sakkiz yuz'
    if n6==9:
        n6 = 'to\'qqiz yuz'
    if n5 == 1:
        n5 = "o'n"
    if n5 == 2:
        n5 = "yigirma"
    if n5 == 3:
        n5 = "o'tiiz"
    if n5 == 4:
        n5 = "qirq"
    if n5 == 5:
        n5 = "ellik"
    if n5 == 6:
        n5 = "olmish"
    if n5 == 7:
        n5 = "yetmish"
    if n5 == 8:
        n5 = "sakson"
    if n5 == 1:
        n5 = "to'qson"
    if n4==1:
        n4 = 'bir'
    if n4==2:
        n4 = 'ikki'
    if n4==3:
        n4 = 'uch'
    if n4==4:
        n4 = 'to\'rt'
    if n4==5:
        n4 = 'besh'
    if n4==6:
        n4 = 'olti'
    if n4==7:
        n4 = 'yetti'
    if n4==8:
        n4 = 'sakkiz'
    if n4==9:
        n4 = 'to\'qqiz'                            
    print(n6, n5, n4, 'ming', end=' ')    

if n3==1:
    n3 = 'bir yuz'
if n3==2:
    n3 = 'ikki yuz'
if n3==3:
    n3 = 'uch yuz'
if n3==4:
    n3 = 'to\'rt yuz'
if n3==5:
    n3 = 'besh yuz'
if n3==6:
    n3 = 'olti yuz'
if n3==7:
    n3 = 'yetti yuz'
if n3==8:
    n3 = 'sakkiz yuz'
if n3==9:
    n3 = 'to\'qqiz yuz'
if n2 == 1:
    n2 = "o'n"
if n2 == 2:
    n2 = "yigirma"
if n2 == 3:
    n2 = "o'tiiz"
if n2 == 4:
    n2 = "qirq"
if n2 == 5:
    n2 = "ellik"
if n2 == 6:
    n2 = "olmish"
if n2 == 7:
    n2 = "yetmish"
if n2 == 8:
    n2 = "sakson"
if n2 == 1:
    n2 = "to'qson"    
    
if n1==1:
    n1 = 'bir'
if n1==2:
    n1 = 'ikki'
if n1==3:
    n1 = 'uch'
if n1==4:
    n1 = 'to\'rt'
if n1==5:
    n1 = 'besh'
if n1==6:
    n1 = 'olti'
if n1==7:
    n1 = 'yetti'
if n1==8:
    n1 = 'sakkiz'
if n1==9:
    n1 = 'to\'qqiz'
    
print(n3,n2,n1)
